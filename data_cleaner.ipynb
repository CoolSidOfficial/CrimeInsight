# %%
import pandas as pd

# %%
df=pd.read_csv("crime_dataset_india.csv")

# %%
df.head()
# Out:
#    Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0              1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1              2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2              3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3              4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4              5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
#
#         City  Crime Code Crime Description  Victim Age Victim Gender  \
# 0  Ahmedabad         576    IDENTITY THEFT          16             M
# 1    Chennai         128          HOMICIDE          37             M
# 2   Ludhiana         271        KIDNAPPING          48             F
# 3       Pune         170          BURGLARY          49             F
# 4       Pune         421         VANDALISM          30             F
#
#     Weapon Used   Crime Domain  Police Deployed Case Closed  Date Case Closed
# ...

# %%
df.drop(columns="Date Reported",inplace=True)

# %%
df.drop(columns="Report Number",inplace=True)

# %%
df
# Out:
#       Date of Occurrence Time of Occurrence       City  Crime Code  \
# 0       01-01-2020 00:00   01-01-2020 01:11  Ahmedabad         576
# 1       01-01-2020 01:00   01-01-2020 06:26    Chennai         128
# 2       01-01-2020 02:00   01-01-2020 14:30   Ludhiana         271
# 3       01-01-2020 03:00   01-01-2020 14:46       Pune         170
# 4       01-01-2020 04:00   01-01-2020 16:51       Pune         421
# ...                  ...                ...        ...         ...
# 40155   07-31-2024 03:00   31-07-2024 05:05    Kolkata         312
# 40156   07-31-2024 04:00   31-07-2024 04:14     Mumbai         300
# 40157   07-31-2024 05:00   31-07-2024 21:33     Kanpur         423
# 40158   07-31-2024 06:00   31-07-2024 11:05      Patna         311
# 40159   07-31-2024 07:00   31-07-2024 17:19      Delhi         193
#
#         Crime Description  Victim Age Victim Gender   Weapon Used  \
# 0          IDENTITY THEFT          16             M  Blunt Object
# ...

# %%
df

# %%
df.drop(columns='Crime Code', inplace=True)

# %%
df
# Out:
#       Date of Occurrence Time of Occurrence       City   Crime Description  \
# 0       01-01-2020 00:00   01-01-2020 01:11  Ahmedabad      IDENTITY THEFT
# 1       01-01-2020 01:00   01-01-2020 06:26    Chennai            HOMICIDE
# 2       01-01-2020 02:00   01-01-2020 14:30   Ludhiana          KIDNAPPING
# 3       01-01-2020 03:00   01-01-2020 14:46       Pune            BURGLARY
# 4       01-01-2020 04:00   01-01-2020 16:51       Pune           VANDALISM
# ...                  ...                ...        ...                 ...
# 40155   07-31-2024 03:00   31-07-2024 05:05    Kolkata      COUNTERFEITING
# 40156   07-31-2024 04:00   31-07-2024 04:14     Mumbai  ILLEGAL POSSESSION
# 40157   07-31-2024 05:00   31-07-2024 21:33     Kanpur    VEHICLE - STOLEN
# 40158   07-31-2024 06:00   31-07-2024 11:05      Patna      SEXUAL ASSAULT
# 40159   07-31-2024 07:00   31-07-2024 17:19      Delhi   DOMESTIC VIOLENCE
#
# ...

# %%
df.drop(columns='Date Case Closed', inplace=True)

# %%
df
# Out:
#       Date of Occurrence Time of Occurrence       City   Crime Description  \
# 0       01-01-2020 00:00   01-01-2020 01:11  Ahmedabad      IDENTITY THEFT
# 1       01-01-2020 01:00   01-01-2020 06:26    Chennai            HOMICIDE
# 2       01-01-2020 02:00   01-01-2020 14:30   Ludhiana          KIDNAPPING
# 3       01-01-2020 03:00   01-01-2020 14:46       Pune            BURGLARY
# 4       01-01-2020 04:00   01-01-2020 16:51       Pune           VANDALISM
# ...                  ...                ...        ...                 ...
# 40155   07-31-2024 03:00   31-07-2024 05:05    Kolkata      COUNTERFEITING
# 40156   07-31-2024 04:00   31-07-2024 04:14     Mumbai  ILLEGAL POSSESSION
# 40157   07-31-2024 05:00   31-07-2024 21:33     Kanpur    VEHICLE - STOLEN
# 40158   07-31-2024 06:00   31-07-2024 11:05      Patna      SEXUAL ASSAULT
# 40159   07-31-2024 07:00   31-07-2024 17:19      Delhi   DOMESTIC VIOLENCE
#
# ...

# %%
df.drop(columns="Date of Occurrence",inplace=True)

# %%
df.drop(columns="Police Deployed",inplace=True)

# %%
print(df)
# Out:
#       Time of Occurrence       City   Crime Description  Victim Age  \
# 0       01-01-2020 01:11  Ahmedabad      IDENTITY THEFT          16
# 1       01-01-2020 06:26    Chennai            HOMICIDE          37
# 2       01-01-2020 14:30   Ludhiana          KIDNAPPING          48
# 3       01-01-2020 14:46       Pune            BURGLARY          49
# 4       01-01-2020 16:51       Pune           VANDALISM          30
# ...                  ...        ...                 ...         ...
# 40155   31-07-2024 05:05    Kolkata      COUNTERFEITING          78
# 40156   31-07-2024 04:14     Mumbai  ILLEGAL POSSESSION          75
# 40157   31-07-2024 21:33     Kanpur    VEHICLE - STOLEN          68
# 40158   31-07-2024 11:05      Patna      SEXUAL ASSAULT          11
# 40159   31-07-2024 17:19      Delhi   DOMESTIC VIOLENCE          43
#
#       Victim Gender   Weapon Used   Crime Domain Case Closed  Date Case Closed
# ...

# %%
df
# Out:
#       Time of Occurrence       City   Crime Description  Victim Age  \
# 0       01-01-2020 01:11  Ahmedabad      IDENTITY THEFT          16
# 1       01-01-2020 06:26    Chennai            HOMICIDE          37
# 2       01-01-2020 14:30   Ludhiana          KIDNAPPING          48
# 3       01-01-2020 14:46       Pune            BURGLARY          49
# 4       01-01-2020 16:51       Pune           VANDALISM          30
# ...                  ...        ...                 ...         ...
# 40155   31-07-2024 05:05    Kolkata      COUNTERFEITING          78
# 40156   31-07-2024 04:14     Mumbai  ILLEGAL POSSESSION          75
# 40157   31-07-2024 21:33     Kanpur    VEHICLE - STOLEN          68
# 40158   31-07-2024 11:05      Patna      SEXUAL ASSAULT          11
# 40159   31-07-2024 17:19      Delhi   DOMESTIC VIOLENCE          43
#
#       Victim Gender   Weapon Used   Crime Domain Case Closed  Date Case Closed
# ...

# %%
df.drop(columns="Case Closed",inplace=True)

# %%
df
# Out:
#       Time of Occurrence       City   Crime Description  Victim Age  \
# 0       01-01-2020 01:11  Ahmedabad      IDENTITY THEFT          16
# 1       01-01-2020 06:26    Chennai            HOMICIDE          37
# 2       01-01-2020 14:30   Ludhiana          KIDNAPPING          48
# 3       01-01-2020 14:46       Pune            BURGLARY          49
# 4       01-01-2020 16:51       Pune           VANDALISM          30
# ...                  ...        ...                 ...         ...
# 40155   31-07-2024 05:05    Kolkata      COUNTERFEITING          78
# 40156   31-07-2024 04:14     Mumbai  ILLEGAL POSSESSION          75
# 40157   31-07-2024 21:33     Kanpur    VEHICLE - STOLEN          68
# 40158   31-07-2024 11:05      Patna      SEXUAL ASSAULT          11
# 40159   31-07-2024 17:19      Delhi   DOMESTIC VIOLENCE          43
#
#       Victim Gender   Weapon Used   Crime Domain
# 0                 M  Blunt Object  Violent Crime
# 1                 M        Poison    Other Crime
# ...

# %%
df["Time of Occurrence"]=pd.to_datetime(df["Time of Occurrence"],dayfirst=True)

# %%
df['Time'] = df['Time of Occurrence'].dt.time

# %%
df.drop(columns="Time of Occurrence")
# Out:
#             City   Crime Description  Victim Age Victim Gender   Weapon Used  \
# 0      Ahmedabad      IDENTITY THEFT          16             M  Blunt Object
# 1        Chennai            HOMICIDE          37             M        Poison
# 2       Ludhiana          KIDNAPPING          48             F  Blunt Object
# 3           Pune            BURGLARY          49             F       Firearm
# 4           Pune           VANDALISM          30             F         Other
# ...          ...                 ...         ...           ...           ...
# 40155    Kolkata      COUNTERFEITING          78             F       Firearm
# 40156     Mumbai  ILLEGAL POSSESSION          75             F           NaN
# 40157     Kanpur    VEHICLE - STOLEN          68             M         Other
# 40158      Patna      SEXUAL ASSAULT          11             M  Blunt Object
# 40159      Delhi   DOMESTIC VIOLENCE          43             F        Poison
#
#         Crime Domain      Time
# ...

# %%
df.drop(columns="Weapon Used",inplace=True)

# %%
df.drop(columns="Crime Domain",inplace=True)

# %%
df
# Out:
#        Time of Occurrence       City   Crime Description  Victim Age  \
# 0     2020-01-01 01:11:00  Ahmedabad      IDENTITY THEFT          16
# 1     2020-01-01 06:26:00    Chennai            HOMICIDE          37
# 2     2020-01-01 14:30:00   Ludhiana          KIDNAPPING          48
# 3     2020-01-01 14:46:00       Pune            BURGLARY          49
# 4     2020-01-01 16:51:00       Pune           VANDALISM          30
# ...                   ...        ...                 ...         ...
# 40155 2024-07-31 05:05:00    Kolkata      COUNTERFEITING          78
# 40156 2024-07-31 04:14:00     Mumbai  ILLEGAL POSSESSION          75
# 40157 2024-07-31 21:33:00     Kanpur    VEHICLE - STOLEN          68
# 40158 2024-07-31 11:05:00      Patna      SEXUAL ASSAULT          11
# 40159 2024-07-31 17:19:00      Delhi   DOMESTIC VIOLENCE          43
#
#       Victim Gender      Time
# 0                 M  01:11:00
# 1                 M  06:26:00
# 2                 F  14:30:00
# ...

# %%
df.to_csv("processed_file.csv", index=False)

# %%
print(df.head())
# Out:
#    Time of Occurrence       City Crime Description  Victim Age Victim Gender  \
# 0 2020-01-01 01:11:00  Ahmedabad    IDENTITY THEFT          16             M
# 1 2020-01-01 06:26:00    Chennai          HOMICIDE          37             M
# 2 2020-01-01 14:30:00   Ludhiana        KIDNAPPING          48             F
# 3 2020-01-01 14:46:00       Pune          BURGLARY          49             F
# 4 2020-01-01 16:51:00       Pune         VANDALISM          30             F
#
#        Time
# 0  01:11:00
# 1  06:26:00
# 2  14:30:00
# 3  14:46:00
# 4  16:51:00
